# %% [markdown]
# <a href="https://colab.research.google.com/github/anajulidorio/estrutura_de_dados/blob/main/003%20-%20vetores%20n%C3%A3o%20ordenados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# exercício 1:

# %%
class VetorNaoOrdenado:
  def __init__(self, capacidade):
    self.capacidade = capacidade
    self.ultima_posicao = -1
    self.valores = [''] * capacidade

  def inserir (self, valor):
    if self.ultima_posicao == self.capacidade - 1:
      print("vetor cheio")
    else:
      self.ultima_posicao += 1
      self.valores[self.ultima_posicao] = valor

  def imprimir(self):
    if self.ultima_posicao == -1:
      print("vetor vazio")
    else:
      for i in range(self.ultima_posicao + 1):
        print("Posição {} | Valor {}".format(i, self.valores[i]))

  def pesquisar(self, valor):
    for i in range(self.ultima_posicao + 1):
      if self.valores[i] == valor:
        return i
    return -1

  def excluir(self, valor):
    posicao = self.pesquisar(valor)
    if posicao == -1:
      return -1
    else:
      for i in range(posicao, self.ultima_posicao):
        self.valores[i] = self.valores[i+1]
        self.ultima_posicao -= 1


meu_vetor = VetorNaoOrdenado (5)
meu_vetor.imprimir()
meu_vetor.inserir('J')
meu_vetor.inserir('U')
meu_vetor.inserir('L')
meu_vetor.inserir('I')
meu_vetor.inserir('A')

meu_vetor.imprimir()

print(meu_vetor.pesquisar('U'))
print(meu_vetor.pesquisar('I'))
print(meu_vetor.pesquisar('L'))

meu_vetor.excluir('J')
meu_vetor.excluir('L')
meu_vetor.excluir('A')

meu_vetor.imprimir()
# Out:
# vetor vazio
# Posição 0 | Valor J
# Posição 1 | Valor U
# Posição 2 | Valor L
# Posição 3 | Valor I
# Posição 4 | Valor A
# 1
# 3
# 2
# Posição 0 | Valor U

# %% [markdown]
# exercício 2:
#
# a - a variável última posição | b - 3 | c - 2 | d - s, a, t, c | e - 2 | f - se encontrou retorna a posição do elemento, senão retorna -1
