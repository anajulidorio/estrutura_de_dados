# %% [markdown]
# <a href="https://colab.research.google.com/github/anajulidorio/estrutura_de_dados/blob/main/exerc%C3%ADcios%20-%20algoritmos%20de%20ordena%C3%A7%C3%A3o%20II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def merge_sort(lista):
  #divisão da lista
  if len(lista) > 1:
    divisao = len(lista) // 2
    esquerda = lista[:divisao]
    direita = lista[divisao:]

    merge_sort(esquerda)
    merge_sort(direita)

    i = j = k = 0

    while i < len(esquerda) and j < len(direita):
      if esquerda[i] < direita[j]:
        lista[k] = esquerda[i]
        i += 1
      else:
        lista[k] = direita[j]
        j += 1
      k += 1

    while i < len(esquerda):
      lista[k] = esquerda[i]
      i += 1
      k += 1

    while j < len(direita):
      lista[k] = direita[j]
      j += 1
      k += 1

    return lista

lista_num = [random.randint(0, 10000) for _ in range(1000)]

lista_nomes = ['Joaquim Santos', 'Rafaela Souza', 'Clara Souza', 'Quintino Rodrigues', 'Nicolas Almeida',
 'Nicolas Almeida', 'Lucas Rodrigues', 'Wellington Pereira', 'Lucas Rodrigues', 'Karla Oliveira',
 'Alice Silva', 'Elena Santos', 'Karla Souza', 'Rafaela Santos', 'Elena Souza', 'Clara Costa',
 'Sofia Silva', 'Yara Santos', 'Gabriela Souza', 'Joaquim Almeida', 'Daniel Souza', 'Hugo Gomes',
 'Rafaela Ferreira', 'Nicolas Gomes', 'Benjamin Pereira', 'Gabriela Costa', 'Joaquim Almeida',
 'Nicolas Almeida', 'Lucas Ferreira', 'Isabela Rodrigues', 'Fabio Oliveira', 'Hugo Pereira',
 'Ximena Oliveira', 'Thiago Santos', 'Paulo Rodrigues', 'Nicolas Oliveira', 'Karla Souza',
 'Yara Ferreira', 'Vitor Pereira', 'Thiago Ferreira', 'Benjamin Santos', 'Thiago Silva',
 'Mariana Pereira', 'Olivia Santos', 'Lucas Pereira', 'Isabela Pereira', 'Elena Almeida',
 'Paulo Ferreira', 'Rafaela Silva', 'Joaquim Rodrigues', 'Ursula Rodrigues', 'Vitor Gomes',
 'Gabriela Gomes', 'Ximena Silva', 'Sofia Santos', 'Paulo Costa', 'Rafaela Costa', 'Karla Souza',
 'Gabriela Oliveira', 'Sofia Pereira', 'Karla Pereira', 'Gabriela Costa', 'Yara Rodrigues',
 'Quintino Rodrigues', 'Fabio Santos', 'Ximena Almeida', 'Rafaela Gomes', 'Wellington Costa',
 'Lucas Costa', 'Quintino Almeida', 'Joaquim Rodrigues', 'Olivia Oliveira', 'Rafaela Silva',
 'Ximena Oliveira', 'Karla Rodrigues', 'Gabriela Silva', 'Rafaela Santos', 'Wellington Rodrigues',
 'Rafaela Almeida', 'Thiago Silva', 'Hugo Souza', 'Olivia Santos', 'Rafaela Pereira',
 'Joaquim Rodrigues', 'Nicolas Rodrigues', 'Vitor Santos', 'Fabio Costa', 'Isabela Rodrigues',
 'Fabio Ferreira', 'Nicolas Souza', 'Rafaela Oliveira', 'Clara Gomes', 'Wellington Santos',
 'Ximena Rodrigues', 'Sofia Gomes', 'Benjamin Gomes', 'Alice Almeida', 'Nicolas Souza',
 'Wellington Oliveira', 'Karla Pereira', 'Fabio Rodrigues', 'Sofia Pereira', 'Paulo Gomes',
 'Alice Gomes', 'Benjamin Pereira', 'Nicolas Rodrigues', 'Alice Gomes', 'Nicolas Rodrigues',
 'Lucas Ferreira', 'Daniel Oliveira', 'Yara Rodrigues', 'Benjamin Costa',
 'Hugo Gomes', 'Ximena Silva', 'Karla Oliveira', 'Nicolas Oliveira', 'Fabio Pereira', 'Joaquim Souza']

print("lista ordenada de números: ", merge_sort(lista_num))
print("lista ordenada de nomes: ", merge_sort(lista_nomes))
# Out:
# lista ordenada de números:  [3, 35, 54, 54, 74, 92, 93, 100, 102, 111, 124, 137, 163, 173, 186, 218, 220, 236, 240, 244, 275, 288, 308, 314, 329, 337, 368, 375, 390, 429, 430, 448, 469, 470, 483, 485, 489, 510, 517, 519, 521, 531, 535, 541, 564, 591, 602, 632, 635, 638, 639, 646, 658, 660, 666, 668, 683, 689, 706, 709, 710, 711, 712, 716, 722, 734, 734, 758, 761, 763, 772, 785, 788, 797, 804, 806, 813, 838, 840, 844, 860, 869, 869, 879, 894, 903, 913, 928, 933, 938, 941, 949, 957, 960, 975, 979, 983, 989, 990, 994, 1002, 1014, 1015, 1019, 1036, 1037, 1050, 1052, 1054, 1064, 1067, 1073, 1084, 1090, 1095, 1096, 1103, 1104, 1128, 1144, 1148, 1149, 1157, 1158, 1159, 1164, 1167, 1171, 1199, 1205, 1223, 1226, 1230, 1234, 1235, 1245, 1248, 1257, 1260, 1263, 1309, 1316, 1319, 1336, 1347, 1352, 1353, 1360, 1374, 1412, 1418, 1439, 1443, 1450, 1454, 1465, 1473, 1485, 1487, 1508, 1513, 1516, 1524, 1531, 1533, 1533, 1553, 1561, 1562, 1563, 1566, 1569, 1575, 1576, 1584, 1590, 1604, 1619, 1620, 164
# ...

# %%
import random

def particao(lista, inicio, final):
  pivo = lista[final]
  i = inicio - 1

  for j in range(inicio, final):
    if lista[j] <= pivo:
      i += 1
      lista[i], lista[j] = lista[j], lista[i]

  lista[i + 1], lista[final] = lista[final], lista [i + 1]

  return i + 1

def quick_sort(lista, inicio, final):
  if inicio < final:
    posicao = particao(lista, inicio, final)

  #esquerda
    quick_sort(lista, inicio, posicao - 1)

  #direita
    quick_sort(lista, posicao + 1, final)

  return lista

lista_num = [random.randint(0, 10000) for _ in range(1000)]

lista_nomes = ['Joaquim Santos', 'Rafaela Souza', 'Clara Souza', 'Quintino Rodrigues', 'Nicolas Almeida',
 'Nicolas Almeida', 'Lucas Rodrigues', 'Wellington Pereira', 'Lucas Rodrigues', 'Karla Oliveira',
 'Alice Silva', 'Elena Santos', 'Karla Souza', 'Rafaela Santos', 'Elena Souza', 'Clara Costa',
 'Sofia Silva', 'Yara Santos', 'Gabriela Souza', 'Joaquim Almeida', 'Daniel Souza', 'Hugo Gomes',
 'Rafaela Ferreira', 'Nicolas Gomes', 'Benjamin Pereira', 'Gabriela Costa', 'Joaquim Almeida',
 'Nicolas Almeida', 'Lucas Ferreira', 'Isabela Rodrigues', 'Fabio Oliveira', 'Hugo Pereira',
 'Ximena Oliveira', 'Thiago Santos', 'Paulo Rodrigues', 'Nicolas Oliveira', 'Karla Souza',
 'Yara Ferreira', 'Vitor Pereira', 'Thiago Ferreira', 'Benjamin Santos', 'Thiago Silva',
 'Mariana Pereira', 'Olivia Santos', 'Lucas Pereira', 'Isabela Pereira', 'Elena Almeida',
 'Paulo Ferreira', 'Rafaela Silva', 'Joaquim Rodrigues', 'Ursula Rodrigues', 'Vitor Gomes',
 'Gabriela Gomes', 'Ximena Silva', 'Sofia Santos', 'Paulo Costa', 'Rafaela Costa', 'Karla Souza',
 'Gabriela Oliveira', 'Sofia Pereira', 'Karla Pereira', 'Gabriela Costa', 'Yara Rodrigues',
 'Quintino Rodrigues', 'Fabio Santos', 'Ximena Almeida', 'Rafaela Gomes', 'Wellington Costa',
 'Lucas Costa', 'Quintino Almeida', 'Joaquim Rodrigues', 'Olivia Oliveira', 'Rafaela Silva',
 'Ximena Oliveira', 'Karla Rodrigues', 'Gabriela Silva', 'Rafaela Santos', 'Wellington Rodrigues',
 'Rafaela Almeida', 'Thiago Silva', 'Hugo Souza', 'Olivia Santos', 'Rafaela Pereira',
 'Joaquim Rodrigues', 'Nicolas Rodrigues', 'Vitor Santos', 'Fabio Costa', 'Isabela Rodrigues',
 'Fabio Ferreira', 'Nicolas Souza', 'Rafaela Oliveira', 'Clara Gomes', 'Wellington Santos',
 'Ximena Rodrigues', 'Sofia Gomes', 'Benjamin Gomes', 'Alice Almeida', 'Nicolas Souza',
 'Wellington Oliveira', 'Karla Pereira', 'Fabio Rodrigues', 'Sofia Pereira', 'Paulo Gomes',
 'Alice Gomes', 'Benjamin Pereira', 'Nicolas Rodrigues', 'Alice Gomes', 'Nicolas Rodrigues',
 'Lucas Ferreira', 'Daniel Oliveira', 'Yara Rodrigues', 'Benjamin Costa',
 'Hugo Gomes', 'Ximena Silva', 'Karla Oliveira', 'Nicolas Oliveira', 'Fabio Pereira', 'Joaquim Souza']

print("lista ordenada de números: ", quick_sort(lista_num, 0, len(lista_num) - 1))
print("lista ordenada de nomes: ", quick_sort(lista_nomes, 0, len(lista_nomes) - 1))
# Out:
# lista ordenada de números:  [31, 34, 37, 65, 92, 95, 105, 111, 126, 135, 159, 162, 162, 163, 169, 169, 176, 186, 190, 198, 207, 239, 246, 249, 252, 264, 265, 265, 286, 288, 293, 298, 301, 306, 319, 319, 322, 332, 335, 376, 377, 397, 437, 439, 440, 444, 467, 487, 511, 517, 525, 537, 555, 563, 574, 587, 588, 609, 623, 631, 636, 637, 650, 654, 674, 691, 695, 700, 703, 737, 737, 747, 748, 776, 781, 784, 809, 830, 847, 863, 870, 871, 889, 893, 901, 905, 911, 947, 951, 954, 966, 974, 979, 982, 984, 984, 987, 1002, 1022, 1025, 1030, 1030, 1035, 1046, 1051, 1064, 1065, 1079, 1110, 1115, 1119, 1151, 1160, 1161, 1166, 1173, 1179, 1182, 1185, 1186, 1198, 1200, 1203, 1210, 1220, 1273, 1275, 1276, 1277, 1279, 1279, 1279, 1288, 1324, 1339, 1353, 1354, 1357, 1372, 1379, 1381, 1404, 1411, 1417, 1420, 1427, 1427, 1441, 1489, 1495, 1495, 1497, 1523, 1532, 1544, 1549, 1553, 1555, 1555, 1556, 1563, 1564, 1564, 1573, 1579, 1584, 1609, 1615, 1616, 1627, 1647, 1649, 1678, 1683, 1691, 1721, 1728, 1740, 1741
# ...

# %% [markdown]
# 3 - d. quick_sort( array, 0, len(array) – 1);
